# %% [markdown]
# # 03 — Prototype Proteins: Reproduce Figure 3
#
# Ordered (P15121), Disordered (A0A0G2L439), Mixed (Q9VQS4).
# Target H_p values: 0.04, 0.27, 0.28.
# Placeholder — to be filled in **Week 1, Day 5**.
